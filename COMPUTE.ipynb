# %%
spark.sql("""
  CREATE OR REPLACE TABLE workspace.default.nasledky
  AS
  SELECT
    CAST(p1 AS STRING) AS p1,
    CAST(id_vozidla AS STRING) AS id_vozidla,
    CAST(p59a AS STRING) AS p59a,
    CAST(p59b AS STRING) AS p59b,
    CAST(p59c AS STRING) AS p59c,
    TRY_CAST(p59d AS INTEGER) AS p59d,
    CAST(p59e AS STRING) AS p59e,
    CAST(p59f AS STRING) AS p59f,
    CAST(p59g AS STRING) AS p59g

  FROM workspace.default.nasledky
""ted_rows: bigint]$0");

# %%
spark.sql("""
  CREATE OR REPLACE TABLE workspace.default.chodci
  AS
  SELECT
    CAST(p1 AS STRING) AS p1,
    CAST(p29 AS STRING) AS p29,
    CAST(p29a AS STRING) AS p29a,
    CAST(p29b AS STRING) AS p29b,
    CAST(p30 AS STRING) AS p30,
    CAST(p30a AS STRING) AS p30a,
    CAST(p30b AS STRING) AS p30b,
    CAST(p31 AS STRING) AS p31,
    CAST(p32 AS STRING) AS p32,
    CAST(p33c AS STRING) AS p33c,
    CAST(p33d AS STRING) AS p33d,
    CAST(p33e AS STRING) AS p33e,
    CAST(p33f AS STRING) AS p33f,
    CAST(p33g AS STRING) AS p33g
  FROM workspace.default.chodci
""")

# %%
spark.sql("""
  CREATE OR REPLACE TABLE workspace.default.vozidla
  AS
  SELECT
    CAST(p1 AS STRING) AS p1,
    CAST(id_vozidla AS STRING) AS id_vozidla,
    CAST(p44 AS STRING) AS p44,
    CAST(p45a AS STRING) AS p45a,
    CAST(p45b AS STRING) AS p45b,
    CAST(p45d AS STRING) AS p45d,
    CAST(p45f AS STRING) AS p45f,
    CAST(p47 AS STRING) AS p47,
    CAST(p48a AS STRING) AS p48a,
    CAST(p48b AS STRING) AS p48b,
    CAST(p49 AS STRING) AS p49,
    CAST(p50a AS STRING) AS p50a,
    CAST(p50b AS STRING) AS p50b,
    CAST(p51 AS STRING) AS p51,
    CAST(p52 AS STRING) AS p52,
    CAST(p53 AS INTEGER) AS p53,
    CAST(p55a AS STRING) AS p55a,
    CAST(p55b AS STRING) AS p55b,
    CAST(p56 AS STRING) AS p56,
    CAST(p57 AS STRING) AS p57,
    CAST(p58 AS STRING) AS p58
  FROM workspace.default.vozidla
""")

# %%
spark.sql("""
  CREATE OR REPLACE TABLE workspace.default.nehody
  AS
  SELECT
    CAST(p1 AS STRING) AS p1,
    CAST(p2a AS STRING) AS p2a,
    CAST(p2b AS STRING) AS p2b,
    CAST(p4a AS STRING) AS p4a,
    CAST(p4b AS STRING) AS p4b,
    CAST(p4c AS STRING) AS p4c,
    CAST(p5a AS STRING) AS p5a,
    CAST(p6 AS STRING) AS p6,
    CAST(p7 AS STRING) AS p7,
    CAST(p8 AS STRING) AS p8,
    CAST(p8a AS STRING) AS p8a,
    CAST(p9 AS STRING) AS p9,
    CAST(p10 AS STRING) AS p10,
    CAST(p11 AS STRING) AS p11,
    CAST(p11a AS STRING) AS p11a,
    CAST(p12 AS STRING) AS p12,
    CAST(p13a AS INTEGER) AS p13a,
    CAST(p13b AS INTEGER) AS p13b,
    CAST(p13c AS INTEGER) AS p13c,
    CAST(p14 AS INTEGER) AS p14,
    CAST(p15 AS STRING) AS p15,
    CAST(p16 AS STRING) AS p16,
    CAST(p17 AS STRING) AS p17,
    CAST(p18 AS STRING) AS p18,
    CAST(p19 AS STRING) AS p19,
    CAST(p20 AS STRING) AS p20,
    CAST(p21 AS STRING) AS p21,
    CAST(p22 AS STRING) AS p22,
    CAST(p23 AS STRING) AS p23,
    CAST(p24 AS STRING) AS p24,
    CAST(p27 AS STRING) AS p27,
    CAST(p28 AS STRING) AS p28,
    CAST(p34 AS INTEGER) AS p34,
    CAST(p35 AS STRING) AS p35,
    CAST(p36 AS STRING) AS p36,
    CAST(p37 AS STRING) AS p37,
    CAST(p38 AS STRING) AS p38,
    CAST(p39 AS STRING) AS p39,
    TO_DATE(Datum_nehody, 'dd.MM.yyyy') AS Datum_nehody,
    Cas
  FROM workspace.default.nehody
""")

# %%
# %sql

SELECT * FROM nehody
WHERE Cas == '06:60'

# %%
# %sql
UPDATE dokumentace_cz
SET popis = TRIM(popis);

# %%
# %sql
SELECT * FROM dokumentace_cz;
